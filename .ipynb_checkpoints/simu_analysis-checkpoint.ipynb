# %%
import subprocess

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
main_res = []
for err_prob in np.arange(0.02,0.115,0.01): 
    
    for checks in range(100,750,25):

        err_prob = round(err_prob,3)

        child = subprocess.Popen(['bash','QKD_pipe','{}'.format(err_prob),'{}'.format(checks)],stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        res = child.communicate()[1].decode('utf-8')

        dic = {}
        
        dic['err_prob'] = err_prob
        dic['n_checks'] = checks
        for each in res.split('\n')[4:-1]:

            for _ in each.split(","): 

                if 'Warning' not in _:

                    key,val = _.split(':')
                    dic[key] = float(val)
                    
        print(dic)
        main_res.append(dic)
# Out:
# {'err_prob': 0.02, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 2.0, 'Average iterations': 249.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3534.469, 'Block counts tot': 444.0, ' with chk errs': 442.0, ' with src errs': 442.0, ' both': 442.0, 'Bit error rate (on message bits only)': 0.01991}
# {'err_prob': 0.02, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 13.0, 'Average iterations': 243.1, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3449.216, 'Block counts tot': 457.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.01934}
# {'err_prob': 0.02, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 76.0, 'Average iterations': 211.1, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 3104.507, 'Block counts tot': 470.0, ' with chk errs': 394.0, ' with src errs': 395.0, ' both': 394.0, 'Bit error rate (on message bits only)': 0.01611}
# {'err_prob': 0.02, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 228.0, 'Average iterations': 137.8, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 2110.089, 'Block counts tot': 484.0, ' with chk errs': 256.0, ' with src errs': 256.0, ' both': 256.0, 'Bit error rate (on message bits only)': 0.009765}
# {'err_prob': 0.02, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 382.0, 'Average iterations': 65.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 1058.051, 'Block counts tot': 500.0, ' with chk errs': 118.0, ' with src errs': 118.0, ' both': 118.0, 'Bit error rate (on message bits only)': 0.004322}
# {'err_prob': 0.02, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 497.0, 'Average iterations': 15.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 269.974, 'Block counts tot': 516.0, ' with chk errs': 19.0, ' with src errs': 20.0, ' both': 19.0, 'Bit error rate (on message bits only)': 0.0006927}
# {'err_prob': 0.02, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 533.0, 'Average iterations': 4.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 89.259, 'Block counts tot': 533.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 551.0, 'Average iterations': 3.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 68.288, 'Block counts tot': 551.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 571.0, 'Average iterations': 2.9, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 63.35, 'Block counts tot': 571.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 592.0, 'Average iterations': 2.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 60.312, 'Block counts tot': 592.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 615.0, 'Average iterations': 2.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 52.539, 'Block counts tot': 615.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 640.0, 'Average iterations': 2.1, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 53.322, 'Block counts tot': 640.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 666.0, 'Average iterations': 1.9, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 49.918, 'Block counts tot': 666.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 1.9, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 53.82, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 1.7, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 52.509, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 54.523, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 53.559, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 54.767, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 54.262, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 1.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 54.487, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 1.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 58.315, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 1.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 60.622, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 1.2, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 63.607, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 1.2, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 63.481, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 1.1, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 66.84, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 1.1, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 72.028, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3691.086, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.03022}
# {'err_prob': 0.03, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3616.074, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.03022}
# {'err_prob': 0.03, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 1.0, 'Average iterations': 249.5, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3791.547, 'Block counts tot': 470.0, ' with chk errs': 469.0, ' with src errs': 469.0, ' both': 469.0, 'Bit error rate (on message bits only)': 0.03009}
# {'err_prob': 0.03, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 13.0, 'Average iterations': 243.9, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 4146.059, 'Block counts tot': 484.0, ' with chk errs': 471.0, ' with src errs': 471.0, ' both': 471.0, 'Bit error rate (on message bits only)': 0.0282}
# {'err_prob': 0.03, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 95.0, 'Average iterations': 205.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 3419.819, 'Block counts tot': 500.0, ' with chk errs': 405.0, ' with src errs': 405.0, ' both': 405.0, 'Bit error rate (on message bits only)': 0.02222}
# {'err_prob': 0.03, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 243.0, 'Average iterations': 138.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 2365.978, 'Block counts tot': 516.0, ' with chk errs': 273.0, ' with src errs': 273.0, ' both': 273.0, 'Bit error rate (on message bits only)': 0.0139}
# {'err_prob': 0.03, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 427.0, 'Average iterations': 58.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 1048.168, 'Block counts tot': 533.0, ' with chk errs': 106.0, ' with src errs': 106.0, ' both': 106.0, 'Bit error rate (on message bits only)': 0.005311}
# {'err_prob': 0.03, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 530.0, 'Average iterations': 16.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 307.109, 'Block counts tot': 551.0, ' with chk errs': 21.0, ' with src errs': 21.0, ' both': 21.0, 'Bit error rate (on message bits only)': 0.001111}
# {'err_prob': 0.03, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 567.0, 'Average iterations': 7.2, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 145.227, 'Block counts tot': 571.0, ' with chk errs': 4.0, ' with src errs': 4.0, ' both': 4.0, 'Bit error rate (on message bits only)': 0.0001551}
# {'err_prob': 0.03, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 592.0, 'Average iterations': 4.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 90.027, 'Block counts tot': 592.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 613.0, 'Average iterations': 4.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 90.305, 'Block counts tot': 615.0, ' with chk errs': 2.0, ' with src errs': 2.0, ' both': 2.0, 'Bit error rate (on message bits only)': 0.0002852}
# {'err_prob': 0.03, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 640.0, 'Average iterations': 3.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 72.674, 'Block counts tot': 640.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 666.0, 'Average iterations': 2.7, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 64.547, 'Block counts tot': 666.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 2.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 63.976, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 2.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 63.077, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 2.2, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 64.725, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 2.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 64.381, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 1.9, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 67.366, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 1.8, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 63.406, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 1.7, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 64.365, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 64.907, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 67.345, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 72.287, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 1.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 71.865, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 1.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 73.693, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 1.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 97.462, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3735.79, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.04031}
# {'err_prob': 0.04, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3736.081, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.04032}
# {'err_prob': 0.04, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3585.865, 'Block counts tot': 470.0, ' with chk errs': 470.0, ' with src errs': 470.0, ' both': 470.0, 'Bit error rate (on message bits only)': 0.04031}
# {'err_prob': 0.04, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 4578.116, 'Block counts tot': 484.0, ' with chk errs': 484.0, ' with src errs': 484.0, ' both': 484.0, 'Bit error rate (on message bits only)': 0.04026}
# {'err_prob': 0.04, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 4.0, 'Average iterations': 248.1, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3703.236, 'Block counts tot': 500.0, ' with chk errs': 496.0, ' with src errs': 496.0, ' both': 496.0, 'Bit error rate (on message bits only)': 0.03921}
# {'err_prob': 0.04, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 28.0, 'Average iterations': 237.2, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 3671.62, 'Block counts tot': 516.0, ' with chk errs': 488.0, ' with src errs': 488.0, ' both': 488.0, 'Bit error rate (on message bits only)': 0.0346}
# {'err_prob': 0.04, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 169.0, 'Average iterations': 175.8, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 2877.2, 'Block counts tot': 533.0, ' with chk errs': 364.0, ' with src errs': 364.0, ' both': 364.0, 'Bit error rate (on message bits only)': 0.02334}
# {'err_prob': 0.04, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 350.0, 'Average iterations': 100.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 1845.253, 'Block counts tot': 551.0, ' with chk errs': 201.0, ' with src errs': 201.0, ' both': 201.0, 'Bit error rate (on message bits only)': 0.01171}
# {'err_prob': 0.04, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 516.0, 'Average iterations': 32.8, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 600.882, 'Block counts tot': 571.0, ' with chk errs': 55.0, ' with src errs': 55.0, ' both': 55.0, 'Bit error rate (on message bits only)': 0.003232}
# {'err_prob': 0.04, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 587.0, 'Average iterations': 8.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 193.353, 'Block counts tot': 592.0, ' with chk errs': 5.0, ' with src errs': 5.0, ' both': 5.0, 'Bit error rate (on message bits only)': 0.0003654}
# {'err_prob': 0.04, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 611.0, 'Average iterations': 6.4, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 134.709, 'Block counts tot': 615.0, ' with chk errs': 4.0, ' with src errs': 4.0, ' both': 4.0, 'Bit error rate (on message bits only)': 0.0001626}
# {'err_prob': 0.04, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 640.0, 'Average iterations': 4.0, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 98.87, 'Block counts tot': 640.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 666.0, 'Average iterations': 3.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 81.433, 'Block counts tot': 666.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 3.2, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 75.75, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 2.9, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 78.171, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 2.6, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 71.602, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 2.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 77.872, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 2.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 73.013, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 2.2, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 71.391, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 2.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 81.67, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 1.9, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 74.272, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 1.8, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 80.897, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 1.7, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 79.024, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 80.929, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 80.131, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 90.389, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3828.636, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.05027}
# {'err_prob': 0.05, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3494.507, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.05028}
# {'err_prob': 0.05, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3579.878, 'Block counts tot': 470.0, ' with chk errs': 470.0, ' with src errs': 470.0, ' both': 470.0, 'Bit error rate (on message bits only)': 0.05027}
# {'err_prob': 0.05, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3846.16, 'Block counts tot': 484.0, ' with chk errs': 484.0, ' with src errs': 484.0, ' both': 484.0, 'Bit error rate (on message bits only)': 0.05028}
# {'err_prob': 0.05, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3795.121, 'Block counts tot': 500.0, ' with chk errs': 500.0, ' with src errs': 500.0, ' both': 500.0, 'Bit error rate (on message bits only)': 0.0502}
# {'err_prob': 0.05, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 2.0, 'Average iterations': 249.1, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3928.504, 'Block counts tot': 516.0, ' with chk errs': 514.0, ' with src errs': 514.0, ' both': 514.0, 'Bit error rate (on message bits only)': 0.04937}
# {'err_prob': 0.05, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 17.0, 'Average iterations': 242.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 3867.588, 'Block counts tot': 533.0, ' with chk errs': 516.0, ' with src errs': 516.0, ' both': 516.0, 'Bit error rate (on message bits only)': 0.04496}
# {'err_prob': 0.05, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 104.0, 'Average iterations': 207.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 3475.846, 'Block counts tot': 551.0, ' with chk errs': 447.0, ' with src errs': 447.0, ' both': 447.0, 'Bit error rate (on message bits only)': 0.03359}
# {'err_prob': 0.05, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 318.0, 'Average iterations': 119.1, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 1982.442, 'Block counts tot': 571.0, ' with chk errs': 253.0, ' with src errs': 253.0, ' both': 253.0, 'Bit error rate (on message bits only)': 0.01753}
# {'err_prob': 0.05, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 523.0, 'Average iterations': 38.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 664.627, 'Block counts tot': 592.0, ' with chk errs': 69.0, ' with src errs': 69.0, ' both': 69.0, 'Bit error rate (on message bits only)': 0.004615}
# {'err_prob': 0.05, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 592.0, 'Average iterations': 16.8, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 315.216, 'Block counts tot': 615.0, ' with chk errs': 23.0, ' with src errs': 23.0, ' both': 23.0, 'Bit error rate (on message bits only)': 0.001328}
# {'err_prob': 0.05, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 639.0, 'Average iterations': 6.1, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 127.574, 'Block counts tot': 640.0, ' with chk errs': 1.0, ' with src errs': 1.0, ' both': 1.0, 'Bit error rate (on message bits only)': 7.25e-05}
# {'err_prob': 0.05, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 666.0, 'Average iterations': 4.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 106.815, 'Block counts tot': 666.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 3.9, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 96.175, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 3.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 88.276, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 3.1, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 81.437, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 2.9, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 81.509, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 2.7, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 79.61, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 2.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 82.316, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 2.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 78.145, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 2.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 80.42, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 2.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 80.039, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 1.9, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 86.824, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 1.8, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 83.716, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 1.7, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 91.258, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 90.819, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.06, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3301.244, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.06051}
# {'err_prob': 0.06, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3564.563, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.06051}
# {'err_prob': 0.06, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3644.653, 'Block counts tot': 470.0, ' with chk errs': 470.0, ' with src errs': 470.0, ' both': 470.0, 'Bit error rate (on message bits only)': 0.06051}
# {'err_prob': 0.06, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3759.706, 'Block counts tot': 484.0, ' with chk errs': 484.0, ' with src errs': 484.0, ' both': 484.0, 'Bit error rate (on message bits only)': 0.06052}
# {'err_prob': 0.06, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3805.616, 'Block counts tot': 500.0, ' with chk errs': 500.0, ' with src errs': 500.0, ' both': 500.0, 'Bit error rate (on message bits only)': 0.06051}
# {'err_prob': 0.06, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3860.649, 'Block counts tot': 516.0, ' with chk errs': 516.0, ' with src errs': 516.0, ' both': 516.0, 'Bit error rate (on message bits only)': 0.0605}
# {'err_prob': 0.06, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 1.0, 'Average iterations': 249.6, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3874.999, 'Block counts tot': 533.0, ' with chk errs': 532.0, ' with src errs': 532.0, ' both': 532.0, 'Bit error rate (on message bits only)': 0.05972}
# {'err_prob': 0.06, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 9.0, 'Average iterations': 246.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 4038.808, 'Block counts tot': 551.0, ' with chk errs': 542.0, ' with src errs': 542.0, ' both': 542.0, 'Bit error rate (on message bits only)': 0.05531}
# {'err_prob': 0.06, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 93.0, 'Average iterations': 213.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 3603.793, 'Block counts tot': 571.0, ' with chk errs': 478.0, ' with src errs': 478.0, ' both': 478.0, 'Bit error rate (on message bits only)': 0.04296}
# {'err_prob': 0.06, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 298.0, 'Average iterations': 133.3, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 2267.775, 'Block counts tot': 592.0, ' with chk errs': 294.0, ' with src errs': 294.0, ' both': 294.0, 'Bit error rate (on message bits only)': 0.0235}
# {'err_prob': 0.06, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 502.0, 'Average iterations': 55.6, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 1001.492, 'Block counts tot': 615.0, ' with chk errs': 113.0, ' with src errs': 113.0, ' both': 113.0, 'Bit error rate (on message bits only)': 0.008095}
# {'err_prob': 0.06, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 624.0, 'Average iterations': 14.8, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 298.525, 'Block counts tot': 640.0, ' with chk errs': 16.0, ' with src errs': 16.0, ' both': 16.0, 'Bit error rate (on message bits only)': 0.001167}
# {'err_prob': 0.06, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 664.0, 'Average iterations': 7.0, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 151.495, 'Block counts tot': 666.0, ' with chk errs': 2.0, ' with src errs': 2.0, ' both': 2.0, 'Bit error rate (on message bits only)': 0.0001502}
# {'err_prob': 0.06, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 5.0, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 118.285, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.06, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 4.2, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 105.829, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.06, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 3.7, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 97.128, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# ...
# {'err_prob': 0.1, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 467.0, 'Average iterations': 95.6, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 1900.507, 'Block counts tot': 695.0, ' with chk errs': 228.0, ' with src errs': 228.0, ' both': 228.0, 'Bit error rate (on message bits only)': 0.02328}
# {'err_prob': 0.1, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 693.0, 'Average iterations': 23.5, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 522.551, 'Block counts tot': 727.0, ' with chk errs': 34.0, ' with src errs': 34.0, ' both': 34.0, 'Bit error rate (on message bits only)': 0.003654}
# {'err_prob': 0.1, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 760.0, 'Average iterations': 8.4, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 207.766, 'Block counts tot': 761.0, ' with chk errs': 1.0, ' with src errs': 1.0, ' both': 1.0, 'Bit error rate (on message bits only)': 0.0001126}
# {'err_prob': 0.1, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 6.2, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 162.552, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 5.0, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 139.572, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 4.3, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 123.303, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 3.8, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 128.033, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 3.5, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 119.708, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 3.1, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 115.645, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 2.9, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 120.054, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 2.7, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 113.961, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 2.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 118.027, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 2.3, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 124.806, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3351.514, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3568.815, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3535.044, 'Block counts tot': 470.0, ' with chk errs': 470.0, ' with src errs': 470.0, ' both': 470.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3811.618, 'Block counts tot': 484.0, ' with chk errs': 484.0, ' with src errs': 484.0, ' both': 484.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3673.021, 'Block counts tot': 500.0, ' with chk errs': 500.0, ' with src errs': 500.0, ' both': 500.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 3975.416, 'Block counts tot': 516.0, ' with chk errs': 516.0, ' with src errs': 516.0, ' both': 516.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 4116.315, 'Block counts tot': 533.0, ' with chk errs': 533.0, ' with src errs': 533.0, ' both': 533.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 4305.172, 'Block counts tot': 551.0, ' with chk errs': 551.0, ' with src errs': 551.0, ' both': 551.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 4283.686, 'Block counts tot': 571.0, ' with chk errs': 571.0, ' with src errs': 571.0, ' both': 571.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 4535.227, 'Block counts tot': 592.0, ' with chk errs': 592.0, ' with src errs': 592.0, ' both': 592.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 5042.91, 'Block counts tot': 615.0, ' with chk errs': 615.0, ' with src errs': 615.0, ' both': 615.0, 'Bit error rate (on message bits only)': 0.1097}
# {'err_prob': 0.11, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 4829.837, 'Block counts tot': 640.0, ' with chk errs': 640.0, ' with src errs': 640.0, ' both': 640.0, 'Bit error rate (on message bits only)': 0.1065}
# {'err_prob': 0.11, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 30.0, 'Average iterations': 240.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 4797.235, 'Block counts tot': 666.0, ' with chk errs': 636.0, ' with src errs': 636.0, ' both': 636.0, 'Bit error rate (on message bits only)': 0.09168}
# {'err_prob': 0.11, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 221.0, 'Average iterations': 179.0, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 3640.308, 'Block counts tot': 695.0, ' with chk errs': 474.0, ' with src errs': 474.0, ' both': 474.0, 'Bit error rate (on message bits only)': 0.05778}
# {'err_prob': 0.11, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 555.0, 'Average iterations': 71.9, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 1602.651, 'Block counts tot': 727.0, ' with chk errs': 172.0, ' with src errs': 172.0, ' both': 172.0, 'Bit error rate (on message bits only)': 0.0184}
# {'err_prob': 0.11, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 729.0, 'Average iterations': 20.4, ' bit changes %': 6.0, ' Decoding time (milli-seconds)': 460.589, 'Block counts tot': 761.0, ' with chk errs': 32.0, ' with src errs': 32.0, ' both': 32.0, 'Bit error rate (on message bits only)': 0.003815}
# {'err_prob': 0.11, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 798.0, 'Average iterations': 7.9, ' bit changes %': 6.0, ' Decoding time (milli-seconds)': 204.573, 'Block counts tot': 800.0, ' with chk errs': 2.0, ' with src errs': 2.0, ' both': 2.0, 'Bit error rate (on message bits only)': 0.0003075}
# {'err_prob': 0.11, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 5.7, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 160.597, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 4.8, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 134.851, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 4.2, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 136.62, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 3.8, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 129.303, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 3.4, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 127.859, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 3.1, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 121.103, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 2.8, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 125.221, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 2.6, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 126.618, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 2.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 134.015, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}

# %%
mainframe = pd.DataFrame(main_res)

# %%
mainframe = pd.read_csv('data.csv')

# %%
mainframe['1-BLER'] = mainframe['valid blocks']/mainframe['Decoded blocks']

# %%
def entropy(err_prob):
    
    return -np.log2(err_prob)*err_prob - (1-err_prob)*np.log2(1-err_prob)

# %%
mainframe['shannon'] = entropy(mainframe['err_prob'])

# %%
mainframe['real_key'] = 1-mainframe['shannon'] - mainframe['n_checks']/mainframe[' encoded block size']

# %%
mainframe['eff_key'] = mainframe['1-BLER']*mainframe['real_key']

# %%
mainframe['eff_key'][mainframe['eff_key']<0] = 0
# Out:
# /var/folders/cm/d0yj9m4s2d32k_fk7zc9vhtr0000gn/T/ipykernel_20631/3690298057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mainframe['eff_key'][mainframe['eff_key']<0] = 0

# %%
plt.figure(figsize=(10,6))

plt.xlabel('number of parity')
plt.ylabel('effective key rate')
for x,y in mainframe.groupby('err_prob'):
    
    #print(x,y)
    plt.plot(y['n_checks'],y['eff_key'],'--',label = "{}%".format(round(100*x)))
    
for a,b in mainframe[mainframe['1-BLER']>=1].groupby('err_prob'):
    ana = b.sort_values('n_checks').head(1)
    
    a = ana['eff_key'].tolist()[0]
    b = ana['n_checks'].tolist()[0]
    #print()
    plt.scatter(b,a)
    
plt.legend(title='QBER')
plt.grid()
plt.show()

# %%
mainframe.columns
# Out:
# Index(['err_prob', 'n_checks', 'Encoded blocks', ' source block size',
#        ' encoded block size', 'Decoded blocks', 'valid blocks',
#        'Average iterations', ' bit changes %',
#        ' Decoding time (milli-seconds)', 'Block counts tot', ' with chk errs',
#        ' with src errs', ' both', 'Bit error rate (on message bits only)',
#        '1-BLER', 'shannon', 'real_key', 'eff_key'],
#       dtype='object')

# %%
1.2*1000*entropy(0.05)
# Out:
# 343.6763485391475

# %%
1000-343
# Out:
# 657

# %%
(1000-343)*608
# Out:
# 399456

# %%
(573/608)* (1-entropy(0.05)-343/1000)
# Out:
# 0.3492689861390741

# %%
0.195/1000
# Out:
# 0.000195

# %%
573/608
# Out:
# 0.9424342105263158

# %%
#mainframe[' Decoding time (milli-seconds)'].unique()

# %%
plt.figure(figsize=(10,6))

plt.xlabel('number of parity')
plt.ylabel('time in mili seconds')
for x,y in mainframe.groupby('err_prob'):
    
    #print(x,y)
    plt.plot(y['n_checks'],y[' Decoding time (milli-seconds)'],'--',label = "{}%".format(round(100*x)),alpha=0.2)
    
for a,b in mainframe[mainframe['1-BLER']>=1].groupby('err_prob'):
    ana = b.sort_values('n_checks').head(1)
    
    a = ana[' Decoding time (milli-seconds)'].tolist()[0]
    b = ana['n_checks'].tolist()[0]
    #print()
    plt.scatter(b,a)
    
plt.legend(title='QBER')
plt.grid()
plt.show()

# %%
x
# Out:
# 11.489999999999998

# %%
plt.title('NUmber of parity bits for given error probability')
for x in np.arange(0.02,0.115,0.01):
    
    plt.bar(x*100,1000*entropy(x),label='{}%'.format(round(100*x),2))
    
plt.legend()
plt.savefig('shannon_parity_number.jpeg')
plt.show()
