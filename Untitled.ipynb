# %%
import subprocess

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
main_res = []
for err_prob in np.arange(0.02,0.115,0.01): 
    
    for checks in range(100,750,25):

        err_prob = round(err_prob,3)

        child = subprocess.Popen(['bash','QKD_pipe','{}'.format(err_prob),'{}'.format(checks)],stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        res = child.communicate()[1].decode('utf-8')

        dic = {}
        
        dic['err_prob'] = err_prob
        dic['n_checks'] = checks
        for each in res.split('\n')[4:-1]:

            for _ in each.split(","): 

                if 'Warning' not in _:

                    key,val = _.split(':')
                    dic[key] = float(val)
                    
        print(dic)
        main_res.append(dic)
# Out:
# {'err_prob': 0.02, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 2.0, 'Average iterations': 249.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.619, 'Block counts tot': 444.0, ' with chk errs': 442.0, ' with src errs': 442.0, ' both': 442.0, 'Bit error rate (on message bits only)': 0.01991}
# {'err_prob': 0.02, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 13.0, 'Average iterations': 243.1, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.605, 'Block counts tot': 457.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.01934}
# {'err_prob': 0.02, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 76.0, 'Average iterations': 211.1, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 7.985, 'Block counts tot': 470.0, ' with chk errs': 394.0, ' with src errs': 395.0, ' both': 394.0, 'Bit error rate (on message bits only)': 0.01611}
# {'err_prob': 0.02, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 228.0, 'Average iterations': 137.8, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.134, 'Block counts tot': 484.0, ' with chk errs': 256.0, ' with src errs': 256.0, ' both': 256.0, 'Bit error rate (on message bits only)': 0.009765}
# {'err_prob': 0.02, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 382.0, 'Average iterations': 65.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.251, 'Block counts tot': 500.0, ' with chk errs': 118.0, ' with src errs': 118.0, ' both': 118.0, 'Bit error rate (on message bits only)': 0.004322}
# {'err_prob': 0.02, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 497.0, 'Average iterations': 15.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.174, 'Block counts tot': 516.0, ' with chk errs': 19.0, ' with src errs': 20.0, ' both': 19.0, 'Bit error rate (on message bits only)': 0.0006927}
# {'err_prob': 0.02, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 533.0, 'Average iterations': 4.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.134, 'Block counts tot': 533.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 551.0, 'Average iterations': 3.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.143, 'Block counts tot': 551.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 571.0, 'Average iterations': 2.9, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.077, 'Block counts tot': 571.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 592.0, 'Average iterations': 2.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.076, 'Block counts tot': 592.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 615.0, 'Average iterations': 2.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.104, 'Block counts tot': 615.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 640.0, 'Average iterations': 2.1, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.043, 'Block counts tot': 640.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 666.0, 'Average iterations': 1.9, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.071, 'Block counts tot': 666.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 1.9, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.05, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 1.7, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.078, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.049, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.074, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.077, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.073, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 1.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.075, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 1.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.075, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 1.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.075, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 1.2, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.047, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 1.2, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.047, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 1.1, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.074, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.02, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 1.1, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.043, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.319, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.03022}
# {'err_prob': 0.03, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.885, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.03022}
# {'err_prob': 0.03, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 1.0, 'Average iterations': 249.5, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.723, 'Block counts tot': 470.0, ' with chk errs': 469.0, ' with src errs': 469.0, ' both': 469.0, 'Bit error rate (on message bits only)': 0.03009}
# {'err_prob': 0.03, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 13.0, 'Average iterations': 243.9, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.573, 'Block counts tot': 484.0, ' with chk errs': 471.0, ' with src errs': 471.0, ' both': 471.0, 'Bit error rate (on message bits only)': 0.0282}
# {'err_prob': 0.03, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 95.0, 'Average iterations': 205.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 8.05, 'Block counts tot': 500.0, ' with chk errs': 405.0, ' with src errs': 405.0, ' both': 405.0, 'Bit error rate (on message bits only)': 0.02222}
# {'err_prob': 0.03, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 243.0, 'Average iterations': 138.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 7.587, 'Block counts tot': 516.0, ' with chk errs': 273.0, ' with src errs': 273.0, ' both': 273.0, 'Bit error rate (on message bits only)': 0.0139}
# {'err_prob': 0.03, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 427.0, 'Average iterations': 58.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 7.803, 'Block counts tot': 533.0, ' with chk errs': 106.0, ' with src errs': 106.0, ' both': 106.0, 'Bit error rate (on message bits only)': 0.005311}
# {'err_prob': 0.03, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 530.0, 'Average iterations': 16.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.16, 'Block counts tot': 551.0, ' with chk errs': 21.0, ' with src errs': 21.0, ' both': 21.0, 'Bit error rate (on message bits only)': 0.001111}
# {'err_prob': 0.03, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 567.0, 'Average iterations': 7.2, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 1.002, 'Block counts tot': 571.0, ' with chk errs': 4.0, ' with src errs': 4.0, ' both': 4.0, 'Bit error rate (on message bits only)': 0.0001551}
# {'err_prob': 0.03, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 592.0, 'Average iterations': 4.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.129, 'Block counts tot': 592.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 613.0, 'Average iterations': 4.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.196, 'Block counts tot': 615.0, ' with chk errs': 2.0, ' with src errs': 2.0, ' both': 2.0, 'Bit error rate (on message bits only)': 0.0002852}
# {'err_prob': 0.03, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 640.0, 'Average iterations': 3.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.104, 'Block counts tot': 640.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 666.0, 'Average iterations': 2.7, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.174, 'Block counts tot': 666.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 2.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.102, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 2.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.082, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 2.2, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.107, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 2.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.097, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 1.9, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.103, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 1.8, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.074, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 1.7, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.084, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.074, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.08, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.073, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 1.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.045, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 1.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.071, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.03, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 1.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.075, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.231, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.04031}
# {'err_prob': 0.04, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.85, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.04032}
# {'err_prob': 0.04, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.565, 'Block counts tot': 470.0, ' with chk errs': 470.0, ' with src errs': 470.0, ' both': 470.0, 'Bit error rate (on message bits only)': 0.04031}
# {'err_prob': 0.04, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.753, 'Block counts tot': 484.0, ' with chk errs': 484.0, ' with src errs': 484.0, ' both': 484.0, 'Bit error rate (on message bits only)': 0.04026}
# {'err_prob': 0.04, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 4.0, 'Average iterations': 248.1, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.243, 'Block counts tot': 500.0, ' with chk errs': 496.0, ' with src errs': 496.0, ' both': 496.0, 'Bit error rate (on message bits only)': 0.03921}
# {'err_prob': 0.04, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 28.0, 'Average iterations': 237.2, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 7.305, 'Block counts tot': 516.0, ' with chk errs': 488.0, ' with src errs': 488.0, ' both': 488.0, 'Bit error rate (on message bits only)': 0.0346}
# {'err_prob': 0.04, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 169.0, 'Average iterations': 175.8, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 8.152, 'Block counts tot': 533.0, ' with chk errs': 364.0, ' with src errs': 364.0, ' both': 364.0, 'Bit error rate (on message bits only)': 0.02334}
# {'err_prob': 0.04, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 350.0, 'Average iterations': 100.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.284, 'Block counts tot': 551.0, ' with chk errs': 201.0, ' with src errs': 201.0, ' both': 201.0, 'Bit error rate (on message bits only)': 0.01171}
# {'err_prob': 0.04, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 516.0, 'Average iterations': 32.8, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 7.828, 'Block counts tot': 571.0, ' with chk errs': 55.0, ' with src errs': 55.0, ' both': 55.0, 'Bit error rate (on message bits only)': 0.003232}
# {'err_prob': 0.04, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 587.0, 'Average iterations': 8.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.211, 'Block counts tot': 592.0, ' with chk errs': 5.0, ' with src errs': 5.0, ' both': 5.0, 'Bit error rate (on message bits only)': 0.0003654}
# {'err_prob': 0.04, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 611.0, 'Average iterations': 6.4, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.216, 'Block counts tot': 615.0, ' with chk errs': 4.0, ' with src errs': 4.0, ' both': 4.0, 'Bit error rate (on message bits only)': 0.0001626}
# {'err_prob': 0.04, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 640.0, 'Average iterations': 4.0, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.139, 'Block counts tot': 640.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 666.0, 'Average iterations': 3.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.164, 'Block counts tot': 666.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 3.2, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.138, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 2.9, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.101, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 2.6, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.102, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 2.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.13, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 2.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.1, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 2.2, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.076, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 2.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.098, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 1.9, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.107, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 1.8, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.076, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 1.7, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.102, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.044, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.072, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.04, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 1.5, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.072, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.587, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.05027}
# {'err_prob': 0.05, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 10.053, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.05028}
# {'err_prob': 0.05, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.261, 'Block counts tot': 470.0, ' with chk errs': 470.0, ' with src errs': 470.0, ' both': 470.0, 'Bit error rate (on message bits only)': 0.05027}
# {'err_prob': 0.05, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.591, 'Block counts tot': 484.0, ' with chk errs': 484.0, ' with src errs': 484.0, ' both': 484.0, 'Bit error rate (on message bits only)': 0.05028}
# {'err_prob': 0.05, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.189, 'Block counts tot': 500.0, ' with chk errs': 500.0, ' with src errs': 500.0, ' both': 500.0, 'Bit error rate (on message bits only)': 0.0502}
# {'err_prob': 0.05, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 2.0, 'Average iterations': 249.1, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.122, 'Block counts tot': 516.0, ' with chk errs': 514.0, ' with src errs': 514.0, ' both': 514.0, 'Bit error rate (on message bits only)': 0.04937}
# {'err_prob': 0.05, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 17.0, 'Average iterations': 242.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 7.493, 'Block counts tot': 533.0, ' with chk errs': 516.0, ' with src errs': 516.0, ' both': 516.0, 'Bit error rate (on message bits only)': 0.04496}
# {'err_prob': 0.05, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 104.0, 'Average iterations': 207.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 7.586, 'Block counts tot': 551.0, ' with chk errs': 447.0, ' with src errs': 447.0, ' both': 447.0, 'Bit error rate (on message bits only)': 0.03359}
# {'err_prob': 0.05, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 318.0, 'Average iterations': 119.1, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 8.026, 'Block counts tot': 571.0, ' with chk errs': 253.0, ' with src errs': 253.0, ' both': 253.0, 'Bit error rate (on message bits only)': 0.01753}
# {'err_prob': 0.05, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 523.0, 'Average iterations': 38.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 7.521, 'Block counts tot': 592.0, ' with chk errs': 69.0, ' with src errs': 69.0, ' both': 69.0, 'Bit error rate (on message bits only)': 0.004615}
# {'err_prob': 0.05, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 592.0, 'Average iterations': 16.8, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.348, 'Block counts tot': 615.0, ' with chk errs': 23.0, ' with src errs': 23.0, ' both': 23.0, 'Bit error rate (on message bits only)': 0.001328}
# {'err_prob': 0.05, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 639.0, 'Average iterations': 6.1, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.199, 'Block counts tot': 640.0, ' with chk errs': 1.0, ' with src errs': 1.0, ' both': 1.0, 'Bit error rate (on message bits only)': 7.25e-05}
# {'err_prob': 0.05, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 666.0, 'Average iterations': 4.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.224, 'Block counts tot': 666.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 3.9, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.208, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 3.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.146, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 3.1, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.136, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 2.9, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.127, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 2.7, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.096, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 2.5, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.075, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 2.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.107, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 2.1, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.096, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 2.0, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.073, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 1.9, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.099, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 1.8, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.081, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 1.7, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 0.083, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.05, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 1.6, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 0.082, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.06, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.787, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.06051}
# {'err_prob': 0.06, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.445, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.06051}
# {'err_prob': 0.06, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.256, 'Block counts tot': 470.0, ' with chk errs': 470.0, ' with src errs': 470.0, ' both': 470.0, 'Bit error rate (on message bits only)': 0.06051}
# {'err_prob': 0.06, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.988, 'Block counts tot': 484.0, ' with chk errs': 484.0, ' with src errs': 484.0, ' both': 484.0, 'Bit error rate (on message bits only)': 0.06052}
# {'err_prob': 0.06, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.424, 'Block counts tot': 500.0, ' with chk errs': 500.0, ' with src errs': 500.0, ' both': 500.0, 'Bit error rate (on message bits only)': 0.06051}
# {'err_prob': 0.06, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.047, 'Block counts tot': 516.0, ' with chk errs': 516.0, ' with src errs': 516.0, ' both': 516.0, 'Bit error rate (on message bits only)': 0.0605}
# {'err_prob': 0.06, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 1.0, 'Average iterations': 249.6, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.914, 'Block counts tot': 533.0, ' with chk errs': 532.0, ' with src errs': 532.0, ' both': 532.0, 'Bit error rate (on message bits only)': 0.05972}
# {'err_prob': 0.06, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 9.0, 'Average iterations': 246.4, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 7.342, 'Block counts tot': 551.0, ' with chk errs': 542.0, ' with src errs': 542.0, ' both': 542.0, 'Bit error rate (on message bits only)': 0.05531}
# {'err_prob': 0.06, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 93.0, 'Average iterations': 213.3, ' bit changes %': 2.0, ' Decoding time (milli-seconds)': 7.506, 'Block counts tot': 571.0, ' with chk errs': 478.0, ' with src errs': 478.0, ' both': 478.0, 'Bit error rate (on message bits only)': 0.04296}
# {'err_prob': 0.06, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 298.0, 'Average iterations': 133.3, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 8.317, 'Block counts tot': 592.0, ' with chk errs': 294.0, ' with src errs': 294.0, ' both': 294.0, 'Bit error rate (on message bits only)': 0.0235}
# {'err_prob': 0.06, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 502.0, 'Average iterations': 55.6, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.54, 'Block counts tot': 615.0, ' with chk errs': 113.0, ' with src errs': 113.0, ' both': 113.0, 'Bit error rate (on message bits only)': 0.008095}
# {'err_prob': 0.06, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 624.0, 'Average iterations': 14.8, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.233, 'Block counts tot': 640.0, ' with chk errs': 16.0, ' with src errs': 16.0, ' both': 16.0, 'Bit error rate (on message bits only)': 0.001167}
# {'err_prob': 0.06, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 664.0, 'Average iterations': 7.0, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.234, 'Block counts tot': 666.0, ' with chk errs': 2.0, ' with src errs': 2.0, ' both': 2.0, 'Bit error rate (on message bits only)': 0.0001502}
# {'err_prob': 0.06, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 695.0, 'Average iterations': 5.0, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.193, 'Block counts tot': 695.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.06, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 727.0, 'Average iterations': 4.2, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.12, 'Block counts tot': 727.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.06, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 761.0, 'Average iterations': 3.7, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.132, 'Block counts tot': 761.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# ...
# {'err_prob': 0.1, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 149.0, 'Average iterations': 199.9, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 7.86, 'Block counts tot': 666.0, ' with chk errs': 517.0, ' with src errs': 517.0, ' both': 517.0, 'Bit error rate (on message bits only)': 0.06063}
# {'err_prob': 0.1, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 467.0, 'Average iterations': 95.6, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.629, 'Block counts tot': 695.0, ' with chk errs': 228.0, ' with src errs': 228.0, ' both': 228.0, 'Bit error rate (on message bits only)': 0.02328}
# {'err_prob': 0.1, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 693.0, 'Average iterations': 23.5, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.158, 'Block counts tot': 727.0, ' with chk errs': 34.0, ' with src errs': 34.0, ' both': 34.0, 'Bit error rate (on message bits only)': 0.003654}
# {'err_prob': 0.1, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 760.0, 'Average iterations': 8.4, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.246, 'Block counts tot': 761.0, ' with chk errs': 1.0, ' with src errs': 1.0, ' both': 1.0, 'Bit error rate (on message bits only)': 0.0001126}
# {'err_prob': 0.1, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 800.0, 'Average iterations': 6.2, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.193, 'Block counts tot': 800.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 5.0, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.193, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 4.3, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.143, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 3.8, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.129, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 3.5, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.136, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 3.1, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.101, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 2.9, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.113, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 2.7, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.102, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 2.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.096, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.1, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 2.3, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.073, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 100, 'Encoded blocks': 444.0, ' source block size': 900.0, ' encoded block size': 1000.0, 'Decoded blocks': 444.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.793, 'Block counts tot': 444.0, ' with chk errs': 444.0, ' with src errs': 444.0, ' both': 444.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 125, 'Encoded blocks': 457.0, ' source block size': 875.0, ' encoded block size': 1000.0, 'Decoded blocks': 457.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.409, 'Block counts tot': 457.0, ' with chk errs': 457.0, ' with src errs': 457.0, ' both': 457.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 150, 'Encoded blocks': 470.0, ' source block size': 850.0, ' encoded block size': 1000.0, 'Decoded blocks': 470.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 8.314, 'Block counts tot': 470.0, ' with chk errs': 470.0, ' with src errs': 470.0, ' both': 470.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 175, 'Encoded blocks': 484.0, ' source block size': 825.0, ' encoded block size': 1000.0, 'Decoded blocks': 484.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.976, 'Block counts tot': 484.0, ' with chk errs': 484.0, ' with src errs': 484.0, ' both': 484.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 200, 'Encoded blocks': 500.0, ' source block size': 800.0, ' encoded block size': 1000.0, 'Decoded blocks': 500.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.61, 'Block counts tot': 500.0, ' with chk errs': 500.0, ' with src errs': 500.0, ' both': 500.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 225, 'Encoded blocks': 516.0, ' source block size': 775.0, ' encoded block size': 1000.0, 'Decoded blocks': 516.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.448, 'Block counts tot': 516.0, ' with chk errs': 516.0, ' with src errs': 516.0, ' both': 516.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 250, 'Encoded blocks': 533.0, ' source block size': 750.0, ' encoded block size': 1000.0, 'Decoded blocks': 533.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 6.946, 'Block counts tot': 533.0, ' with chk errs': 533.0, ' with src errs': 533.0, ' both': 533.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 275, 'Encoded blocks': 551.0, ' source block size': 725.0, ' encoded block size': 1000.0, 'Decoded blocks': 551.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.61, 'Block counts tot': 551.0, ' with chk errs': 551.0, ' with src errs': 551.0, ' both': 551.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 300, 'Encoded blocks': 571.0, ' source block size': 700.0, ' encoded block size': 1000.0, 'Decoded blocks': 571.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.071, 'Block counts tot': 571.0, ' with chk errs': 571.0, ' with src errs': 571.0, ' both': 571.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 325, 'Encoded blocks': 592.0, ' source block size': 675.0, ' encoded block size': 1000.0, 'Decoded blocks': 592.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 7.015, 'Block counts tot': 592.0, ' with chk errs': 592.0, ' with src errs': 592.0, ' both': 592.0, 'Bit error rate (on message bits only)': 0.11}
# {'err_prob': 0.11, 'n_checks': 350, 'Encoded blocks': 615.0, ' source block size': 650.0, ' encoded block size': 1000.0, 'Decoded blocks': 615.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 6.714, 'Block counts tot': 615.0, ' with chk errs': 615.0, ' with src errs': 615.0, ' both': 615.0, 'Bit error rate (on message bits only)': 0.1097}
# {'err_prob': 0.11, 'n_checks': 375, 'Encoded blocks': 640.0, ' source block size': 625.0, ' encoded block size': 1000.0, 'Decoded blocks': 640.0, 'valid blocks': 0.0, 'Average iterations': 250.0, ' bit changes %': 0.0, ' Decoding time (milli-seconds)': 6.987, 'Block counts tot': 640.0, ' with chk errs': 640.0, ' with src errs': 640.0, ' both': 640.0, 'Bit error rate (on message bits only)': 0.1065}
# {'err_prob': 0.11, 'n_checks': 400, 'Encoded blocks': 666.0, ' source block size': 600.0, ' encoded block size': 1000.0, 'Decoded blocks': 666.0, 'valid blocks': 30.0, 'Average iterations': 240.3, ' bit changes %': 1.0, ' Decoding time (milli-seconds)': 6.955, 'Block counts tot': 666.0, ' with chk errs': 636.0, ' with src errs': 636.0, ' both': 636.0, 'Bit error rate (on message bits only)': 0.09168}
# {'err_prob': 0.11, 'n_checks': 425, 'Encoded blocks': 695.0, ' source block size': 575.0, ' encoded block size': 1000.0, 'Decoded blocks': 695.0, 'valid blocks': 221.0, 'Average iterations': 179.0, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.953, 'Block counts tot': 695.0, ' with chk errs': 474.0, ' with src errs': 474.0, ' both': 474.0, 'Bit error rate (on message bits only)': 0.05778}
# {'err_prob': 0.11, 'n_checks': 450, 'Encoded blocks': 727.0, ' source block size': 550.0, ' encoded block size': 1000.0, 'Decoded blocks': 727.0, 'valid blocks': 555.0, 'Average iterations': 71.9, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.185, 'Block counts tot': 727.0, ' with chk errs': 172.0, ' with src errs': 172.0, ' both': 172.0, 'Bit error rate (on message bits only)': 0.0184}
# {'err_prob': 0.11, 'n_checks': 475, 'Encoded blocks': 761.0, ' source block size': 525.0, ' encoded block size': 1000.0, 'Decoded blocks': 761.0, 'valid blocks': 729.0, 'Average iterations': 20.4, ' bit changes %': 6.0, ' Decoding time (milli-seconds)': 0.272, 'Block counts tot': 761.0, ' with chk errs': 32.0, ' with src errs': 32.0, ' both': 32.0, 'Bit error rate (on message bits only)': 0.003815}
# {'err_prob': 0.11, 'n_checks': 500, 'Encoded blocks': 800.0, ' source block size': 500.0, ' encoded block size': 1000.0, 'Decoded blocks': 800.0, 'valid blocks': 798.0, 'Average iterations': 7.9, ' bit changes %': 6.0, ' Decoding time (milli-seconds)': 0.182, 'Block counts tot': 800.0, ' with chk errs': 2.0, ' with src errs': 2.0, ' both': 2.0, 'Bit error rate (on message bits only)': 0.0003075}
# {'err_prob': 0.11, 'n_checks': 525, 'Encoded blocks': 842.0, ' source block size': 475.0, ' encoded block size': 1000.0, 'Decoded blocks': 842.0, 'valid blocks': 842.0, 'Average iterations': 5.7, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.156, 'Block counts tot': 842.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 550, 'Encoded blocks': 888.0, ' source block size': 450.0, ' encoded block size': 1000.0, 'Decoded blocks': 888.0, 'valid blocks': 888.0, 'Average iterations': 4.8, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.145, 'Block counts tot': 888.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 575, 'Encoded blocks': 941.0, ' source block size': 425.0, ' encoded block size': 1000.0, 'Decoded blocks': 941.0, 'valid blocks': 941.0, 'Average iterations': 4.2, ' bit changes %': 5.0, ' Decoding time (milli-seconds)': 0.15, 'Block counts tot': 941.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 600, 'Encoded blocks': 1000.0, ' source block size': 400.0, ' encoded block size': 1000.0, 'Decoded blocks': 1000.0, 'valid blocks': 1000.0, 'Average iterations': 3.8, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.124, 'Block counts tot': 1000.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 625, 'Encoded blocks': 1066.0, ' source block size': 375.0, ' encoded block size': 1000.0, 'Decoded blocks': 1066.0, 'valid blocks': 1066.0, 'Average iterations': 3.4, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.106, 'Block counts tot': 1066.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 650, 'Encoded blocks': 1142.0, ' source block size': 350.0, ' encoded block size': 1000.0, 'Decoded blocks': 1142.0, 'valid blocks': 1142.0, 'Average iterations': 3.1, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.095, 'Block counts tot': 1142.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 675, 'Encoded blocks': 1230.0, ' source block size': 325.0, ' encoded block size': 1000.0, 'Decoded blocks': 1230.0, 'valid blocks': 1230.0, 'Average iterations': 2.8, ' bit changes %': 4.0, ' Decoding time (milli-seconds)': 0.101, 'Block counts tot': 1230.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 700, 'Encoded blocks': 1333.0, ' source block size': 300.0, ' encoded block size': 1000.0, 'Decoded blocks': 1333.0, 'valid blocks': 1333.0, 'Average iterations': 2.6, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.068, 'Block counts tot': 1333.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}
# {'err_prob': 0.11, 'n_checks': 725, 'Encoded blocks': 1454.0, ' source block size': 275.0, ' encoded block size': 1000.0, 'Decoded blocks': 1454.0, 'valid blocks': 1454.0, 'Average iterations': 2.5, ' bit changes %': 3.0, ' Decoding time (milli-seconds)': 0.07, 'Block counts tot': 1454.0, ' with chk errs': 0.0, ' with src errs': 0.0, ' both': 0.0, 'Bit error rate (on message bits only)': 0.0}

# %%
mainframe = pd.DataFrame(main_res)

# %%
mainframe
# Out:
#      err_prob  n_checks  Encoded blocks   source block size  \
# 0        0.02       100           444.0               900.0
# 1        0.02       125           457.0               875.0
# 2        0.02       150           470.0               850.0
# 3        0.02       175           484.0               825.0
# 4        0.02       200           500.0               800.0
# ..        ...       ...             ...                 ...
# 255      0.11       625          1066.0               375.0
# 256      0.11       650          1142.0               350.0
# 257      0.11       675          1230.0               325.0
# 258      0.11       700          1333.0               300.0
# 259      0.11       725          1454.0               275.0
#
#       encoded block size  Decoded blocks  valid blocks  Average iterations  \
# 0                 1000.0           444.0           2.0               249.0
# 1                 1000.0           457.0          13.0               243.1
# 2                 1000.0           470.0          76.0               211.1
# 3                 1000.0           484.0         228.0               137.8
# 4                 1000.0           500.0         382.0                65.4
# ..                   ...             ...           ...                 ...
# 255               1000.0          1066.0        1066.0                 3.4
# 256               1000.0          1142.0        1142.0                 3.1
# 257               1000.0          1230.0        1230.0                 2.8
# 258               1000.0          1333.0        1333.0                 2.6
# 259               1000.0          1454.0        1454.0                 2.5
#
#       bit changes %   Decoding time (milli-seconds)  Block counts tot  \
# 0               0.0                           7.619             444.0
# 1               0.0                           7.605             457.0
# 2               1.0                           7.985             470.0
# 3               1.0                           0.134             484.0
# 4               1.0                           0.251             500.0
# ..              ...                             ...               ...
# 255             4.0                           0.106            1066.0
# 256             4.0                           0.095            1142.0
# 257             4.0                           0.101            1230.0
# 258             3.0                           0.068            1333.0
# 259             3.0                           0.070            1454.0
#
#       with chk errs   with src errs   both  \
# 0             442.0           442.0  442.0
# 1             444.0           444.0  444.0
# 2             394.0           395.0  394.0
# 3             256.0           256.0  256.0
# 4             118.0           118.0  118.0
# ..              ...             ...    ...
# 255             0.0             0.0    0.0
# 256             0.0             0.0    0.0
# 257             0.0             0.0    0.0
# 258             0.0             0.0    0.0
# 259             0.0             0.0    0.0
#
#      Bit error rate (on message bits only)    1-BLER   shannon  real_key
# 0                                 0.019910  0.004505  0.141441  0.758559
# 1                                 0.019340  0.028446  0.141441  0.733559
# 2                                 0.016110  0.161702  0.141441  0.708559
# 3                                 0.009765  0.471074  0.141441  0.683559
# 4                                 0.004322  0.764000  0.141441  0.658559
# ..                                     ...       ...       ...       ...
# 255                               0.000000  1.000000  0.499916 -0.124916
# 256                               0.000000  1.000000  0.499916 -0.149916
# 257                               0.000000  1.000000  0.499916 -0.174916
# 258                               0.000000  1.000000  0.499916 -0.199916
# 259                               0.000000  1.000000  0.499916 -0.224916
#
# [260 rows x 18 columns]

# %%
mainframe['1-BLER'] = mainframe['valid blocks']/mainframe['Decoded blocks']

# %%
def entropy(err_prob):
    
    return -np.log2(err_prob)*err_prob - (1-err_prob)*np.log2(1-err_prob)

# %%
mainframe['shannon'] = entropy(mainframe['err_prob'])

# %%
mainframe['real_key'] = 1-mainframe['shannon'] - mainframe['n_checks']/mainframe[' encoded block size']

# %%
mainframe['eff_key'] = mainframe['1-BLER']*mainframe['real_key']

# %%
mainframe['eff_key'][mainframe['eff_key']<0] = 0
# Out:
# /var/folders/cm/d0yj9m4s2d32k_fk7zc9vhtr0000gn/T/ipykernel_94821/3690298057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mainframe['eff_key'][mainframe['eff_key']<0] = 0

# %%
plt.figure(figsize=(10,6))

plt.xlabel('number of parity')
plt.ylabel('effective key rate')
for x,y in mainframe.groupby('err_prob'):
    
    #print(x,y)
    plt.plot(y['n_checks'],y['eff_key'],'--',label = "{}%".format(round(100*x)))
    
for a,b in mainframe[mainframe['1-BLER']>=0.90].groupby('err_prob'):
    ana = b.sort_values('n_checks').head(1)
    
    a = ana['eff_key'].tolist()[0]
    b = ana['n_checks'].tolist()[0]
    #print()
    plt.scatter(b,a)
    
plt.legend(title='QBER')
plt.grid()
plt.show()

# %%
mainframe.columns
# Out:
# Index(['err_prob', 'n_checks', 'Encoded blocks', ' source block size',
#        ' encoded block size', 'Decoded blocks', 'valid blocks',
#        'Average iterations', ' bit changes %',
#        ' Decoding time (milli-seconds)', 'Block counts tot', ' with chk errs',
#        ' with src errs', ' both', 'Bit error rate (on message bits only)',
#        '1-BLER', 'shannon', 'real_key', 'eff_key'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))

plt.xlabel('number of parity')
plt.ylabel('time in mili seconds')
for x,y in mainframe.groupby('err_prob'):
    
    #print(x,y)
    plt.plot(y['n_checks'],y[' Decoding time (milli-seconds)'],'--',label = "{}%".format(round(100*x)))
    
for a,b in mainframe[mainframe['1-BLER']>=0.90].groupby('err_prob'):
    ana = b.sort_values('n_checks').head(1)
    
    a = ana[' Decoding time (milli-seconds)'].tolist()[0]
    b = ana['n_checks'].tolist()[0]
    #print()
    plt.scatter(b,a)
    
plt.legend(title='QBER')
plt.grid()
plt.show()
